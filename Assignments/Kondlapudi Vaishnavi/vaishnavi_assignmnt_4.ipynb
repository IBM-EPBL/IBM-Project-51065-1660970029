# %% [markdown]
# #importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# #Reading the Dataset

# %%
df = pd.read_csv('/content/spam.csv.xls',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %% [markdown]
# #Process the Data

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,   5, 577,   5],
#        [  0,   0,   0, ...,  47,  41,  49],
#        [  0,   0,   0, ...,   4, 671, 224],
#        ...,
#        [  0,   0,   0, ...,  86,   8, 630],
#        [  0,   0,   0, ..., 685,  18,  72],
#        [  0,   0,   0, ...,  27, 200,  46]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'not',
#  25: 'but',
#  26: 'do',
#  27: 'or',
#  28: 'can',
#  29: 'at',
#  30: 'with',
#  31: "i'm",
#  32: 'will',
#  33: 'be',
#  34: 'get',
#  35: 'ur',
#  36: 'if',
#  37: 'just',
#  38: 'no',
#  39: 'we',
#  40: 'this',
#  41: '4',
#  42: 'gt',
#  43: 'up',
#  44: 'lt',
#  45: 'when',
#  46: 'ok',
#  47: 'all',
#  48: 'go',
#  49: 'free',
#  50: 'from',
#  51: 'how',
#  52: 'out',
#  53: 'know',
#  54: 'what',
#  55: 'got',
#  56: 'like',
#  57: 'good',
#  58: 'then',
#  59: 'come',
#  60: 'was',
#  61: 'only',
#  62: 'its',
#  63: 'time',
#  64: 'day',
#  65: 'am',
#  66: 'love',
#  67: 'send',
#  68: 'want',
#  69: 'there',
#  70: 'text',
#  71: 'as',
#  72: 'he',
#  73: 'one',
#  74: 'txt',
#  75: 'home',
#  76: "i'll",
#  77: 'by',
#  78: 'going',
#  79: 'need',
#  80: 'stop',
#  81: 'r',
#  82: 'about',
#  83: 'see',
#  84: 'lor',
#  85: 'sorry',
#  86: 'still',
#  87: 'n',
#  88: 'da',
#  89: 'back',
#  90: 'k',
#  91: 'our',
#  92: 'dont',
#  93: 'take',
#  94: 'reply',
#  95: 'new',
#  96: 'mobile',
#  97: 'today',
#  98: "don't",
#  99: 'pls',
#  100: 'she',
#  101: 'please',
#  102: 'her',
#  103: 'later',
#  104: 'tell',
#  105: 'here',
#  106: 'week',
#  107: 'they',
#  108: 'any',
#  109: 'phone',
#  110: 'some',
#  111: 'hi',
#  112: 'been',
#  113: '1',
#  114: 'great',
#  115: 'dear',
#  116: 'ì',
#  117: 'think',
#  118: 'msg',
#  119: 'hope',
#  120: 'has',
#  121: 'well',
#  122: 'happy',
#  123: 'night',
#  124: 'oh',
#  125: 'did',
#  126: 'too',
#  127: 'much',
#  128: 'an',
#  129: 'hey',
#  130: 'd',
#  131: 'where',
#  132: 'claim',
#  133: 'him',
#  134: 'more',
#  135: 'c',
#  136: 'who',
#  137: "it's",
#  138: 'number',
#  139: 'www',
#  140: 'message',
#  141: 'wat',
#  142: 'already',
#  143: 'give',
#  144: 'tomorrow',
#  145: 'way',
#  146: 'work',
#  147: 'had',
#  148: 'e',
#  149: 'yes',
#  150: 'make',
#  151: 'prize',
#  152: 'right',
#  153: 'doing',
#  154: '3',
#  155: 'meet',
#  156: 'cash',
#  157: 'yeah',
#  158: 'amp',
#  159: 'after',
#  160: 'ask',
#  161: 'im',
#  162: 'should',
#  163: 'very',
#  164: 'said',
#  165: 'them',
#  166: 'say',
#  167: 'really',
#  168: 'babe',
#  169: 'thanks',
#  170: 'why',
#  171: 'win',
#  172: 'miss',
#  173: 'morning',
#  174: 'life',
#  175: 'would',
#  176: 'last',
#  177: 'also',
#  178: 'b',
#  179: 'cos',
#  180: 'sure',
#  181: 'find',
#  182: 'lol',
#  183: 'won',
#  184: '150p',
#  185: 'anything',
#  186: 'com',
#  187: 'pick',
#  188: 'care',
#  189: 'uk',
#  190: 'min',
#  191: 'every',
#  192: 'nokia',
#  193: 'before',
#  194: 'over',
#  195: 's',
#  196: 'let',
#  197: 'sent',
#  198: 'us',
#  199: 'again',
#  200: 'something',
#  201: 'urgent',
#  202: 'per',
#  203: '5',
#  204: 'off',
#  205: "i've",
#  206: 'place',
#  207: 'could',
#  208: 'cant',
#  209: 'contact',
#  210: 't',
#  211: 'soon',
#  212: 'which',
#  213: 'were',
#  214: 'wait',
#  215: 'went',
#  216: 'feel',
#  217: 'around',
#  218: 'buy',
#  219: 'keep',
#  220: 'money',
#  221: 'ya',
#  222: 'wan',
#  223: "can't",
#  224: 'tonight',
#  225: 'thing',
#  226: 'someone',
#  227: 'many',
#  228: 'first',
#  229: '50',
#  230: 'haha',
#  231: 'even',
#  232: 'tone',
#  233: 'gonna',
#  234: 'wish',
#  235: 'service',
#  236: 'co',
#  237: 'waiting',
#  238: 'nice',
#  239: 'dun',
#  240: 'customer',
#  241: 'chat',
#  242: 'gud',
#  243: 'his',
#  244: 'friends',
#  245: 'x',
#  246: 'leave',
#  247: 'late',
#  248: 'things',
#  249: 'sms',
#  250: 'always',
#  251: 'hello',
#  252: 'other',
#  253: 'sleep',
#  254: 'down',
#  255: 'year',
#  256: 'help',
#  257: 'v',
#  258: "that's",
#  259: 'fine',
#  260: 'people',
#  261: 'next',
#  262: 'heart',
#  263: 'getting',
#  264: 'friend',
#  265: "you're",
#  266: 'may',
#  267: 'told',
#  268: 'special',
#  269: 'lunch',
#  270: 'same',
#  271: 'try',
#  272: '16',
#  273: 'yet',
#  274: 'thk',
#  275: 'ìï',
#  276: 'mins',
#  277: '18',
#  278: 'coming',
#  279: 'use',
#  280: "didn't",
#  281: 'guaranteed',
#  282: 'y',
#  283: 'name',
#  284: 'done',
#  285: 'yup',
#  286: 'class',
#  287: 'few',
#  288: '7',
#  289: 'man',
#  290: '6',
#  291: 'having',
#  292: 'better',
#  293: 'talk',
#  294: 'meeting',
#  295: 'bit',
#  296: 'best',
#  297: 'thought',
#  298: 'stuff',
#  299: 'ready',
#  300: 'being',
#  301: 'ill',
#  302: 'never',
#  303: 'draw',
#  304: 'house',
#  305: 'wk',
#  306: 'car',
#  307: 'long',
#  308: 'than',
#  309: 'live',
#  310: 'dat',
#  311: 'job',
#  312: 'real',
#  313: 'mind',
#  314: 'chance',
#  315: 'finish',
#  316: 'enjoy',
#  317: 'holiday',
#  318: 'å£1',
#  319: 'check',
#  320: 'line',
#  321: 'trying',
#  322: 'account',
#  323: 'another',
#  324: 'receive',
#  325: 'latest',
#  326: 'smile',
#  327: 'because',
#  328: 'sir',
#  329: 'lot',
#  330: 'cool',
#  331: 'cs',
#  332: 'jus',
#  333: 'guess',
#  334: 'might',
#  335: 'big',
#  336: 'lar',
#  337: 'month',
#  338: 'play',
#  339: 'nothing',
#  340: 'god',
#  341: 'liao',
#  342: 'bt',
#  343: 'guys',
#  344: 'days',
#  345: 'wanna',
#  346: 'person',
#  347: 'end',
#  348: 'ah',
#  349: 'problem',
#  350: 'world',
#  351: 'shit',
#  352: 'xxx',
#  353: 'watching',
#  354: 'cost',
#  355: 'girl',
#  356: 'den',
#  357: 'shows',
#  358: 'into',
#  359: 'princess',
#  360: 'tv',
#  361: 'remember',
#  362: 'easy',
#  363: 'quite',
#  364: 'å£1000',
#  365: 'rate',
#  366: 'plan',
#  367: 'pa',
#  368: 'ringtone',
#  369: 'apply',
#  370: 'awarded',
#  371: '9',
#  372: 'thats',
#  373: 'sweet',
#  374: 'box',
#  375: 'two',
#  376: 'early',
#  377: 'pay',
#  378: 'wont',
#  379: 'eat',
#  380: 'reach',
#  381: 'aight',
#  382: 'luv',
#  383: 'offer',
#  384: 'once',
#  385: 'boy',
#  386: '150ppm',
#  387: 'made',
#  388: 'does',
#  389: 'thanx',
#  390: 'ever',
#  391: 'probably',
#  392: 'bed',
#  393: '1st',
#  394: 'fun',
#  395: 'start',
#  396: 'face',
#  397: 'hour',
#  398: 'sat',
#  399: 'word',
#  400: 'kiss',
#  401: 'camera',
#  402: 'watch',
#  403: 'network',
#  404: 'po',
#  405: 'little',
#  406: 'while',
#  407: 'speak',
#  408: 'm',
#  409: 'award',
#  410: 'll',
#  411: 'hear',
#  412: 'video',
#  413: 'half',
#  414: 'weekend',
#  415: 'dinner',
#  416: 'code',
#  417: 'room',
#  418: 'birthday',
#  419: 'look',
#  420: 'forgot',
#  421: 'dunno',
#  422: 'missing',
#  423: 'leh',
#  424: 'bad',
#  425: 'yo',
#  426: 'shopping',
#  427: 'school',
#  428: 'thank',
#  429: 'called',
#  430: 'town',
#  431: '8',
#  432: 'actually',
#  433: 'office',
#  434: 'part',
#  435: 'baby',
#  436: 'tones',
#  437: 'landline',
#  438: "how's",
#  439: 'dad',
#  440: 'selected',
#  441: 'put',
#  442: 'wife',
#  443: 'shall',
#  444: 'dis',
#  445: 'orange',
#  446: 'those',
#  447: 'most',
#  448: 'join',
#  449: 'tmr',
#  450: 'though',
#  451: 'collect',
#  452: 'hav',
#  453: 'minutes',
#  454: 'times',
#  455: 'bring',
#  456: 'everything',
#  457: 'mail',
#  458: 'between',
#  459: 'enough',
#  460: 'means',
#  461: "there's",
#  462: 'texts',
#  463: 'wanted',
#  464: 'afternoon',
#  465: 'maybe',
#  466: 'sexy',
#  467: 'until',
#  468: 'asked',
#  469: 'must',
#  470: 'left',
#  471: 'didnt',
#  472: '2nd',
#  473: 'alright',
#  474: 'fuck',
#  475: 'makes',
#  476: 'juz',
#  477: 'details',
#  478: 'goes',
#  479: 'wif',
#  480: '500',
#  481: 'driving',
#  482: 'stay',
#  483: "he's",
#  484: 'bus',
#  485: 'bored',
#  486: 'missed',
#  487: 'came',
#  488: 'true',
#  489: '10p',
#  490: 'gift',
#  491: '10',
#  492: 'wake',
#  493: 'double',
#  494: 'food',
#  495: 'away',
#  496: 'looking',
#  497: 'yesterday',
#  498: 'says',
#  499: 'show',
#  500: 'haf',
#  501: 'able',
#  502: 'top',
#  503: 'worry',
#  504: 'anyway',
#  505: '000',
#  506: 'wen',
#  507: 'wot',
#  508: 'dude',
#  509: 'g',
#  510: 'pain',
#  511: 'lei',
#  512: 'working',
#  513: 'messages',
#  514: 'calls',
#  515: 'decimal',
#  516: 'havent',
#  517: 'till',
#  518: 'xmas',
#  519: 'mob',
#  520: 'plz',
#  521: 'test',
#  522: "''",
#  523: 'okay',
#  524: 'oso',
#  525: 'else',
#  526: 'colour',
#  527: 'evening',
#  528: "what's",
#  529: 'making',
#  530: 'question',
#  531: 'happen',
#  532: 'ard',
#  533: 're',
#  534: 'bonus',
#  535: 'de',
#  536: 'national',
#  537: 'hot',
#  538: 'hair',
#  539: 'beautiful',
#  540: 'goin',
#  541: 'online',
#  542: 'believe',
#  543: 'abt',
#  544: 'game',
#  545: 'sad',
#  546: 'important',
#  547: 'leaving',
#  548: 'å£5000',
#  549: 'entry',
#  550: 'valid',
#  551: 'tomo',
#  552: 'these',
#  553: 'since',
#  554: 'pics',
#  555: 'å£100',
#  556: 'date',
#  557: 'net',
#  558: 'without',
#  559: 'yourself',
#  560: 'both',
#  561: 'family',
#  562: 'friendship',
#  563: 'todays',
#  564: 'nite',
#  565: 'price',
#  566: 'music',
#  567: 'trip',
#  568: 'together',
#  569: 'words',
#  570: 'attempt',
#  571: 'answer',
#  572: 'id',
#  573: 'run',
#  574: 'years',
#  575: 'saw',
#  576: 'hours',
#  577: 'plus',
#  578: 'update',
#  579: 'feeling',
#  580: 'club',
#  581: "won't",
#  582: 'coz',
#  583: 'awesome',
#  584: 'pub',
#  585: 'mean',
#  586: 'charge',
#  587: "we're",
#  588: 'wid',
#  589: 'tried',
#  590: 'eve',
#  591: 'chikku',
#  592: 'rite',
#  593: 'http',
#  594: 'change',
#  595: 'brother',
#  596: 'drink',
#  597: 'huh',
#  598: 'lets',
#  599: 'vouchers',
#  600: 'shop',
#  601: 'lose',
#  602: 'tot',
#  603: '8007',
#  604: 'å£2000',
#  605: 'private',
#  606: 'points',
#  607: 'movie',
#  608: 'thinking',
#  609: 'guy',
#  610: 'busy',
#  611: "c's",
#  612: 'wil',
#  613: 'weekly',
#  614: 'hurt',
#  615: 'row',
#  616: 'set',
#  617: 'full',
#  618: 'collection',
#  619: 'okie',
#  620: 'pic',
#  621: 'unsubscribe',
#  622: 'sleeping',
#  623: 'noe',
#  624: 'ring',
#  625: 'aft',
#  626: 'gd',
#  627: 'games',
#  628: 'delivery',
#  629: 'smiling',
#  630: 'sch',
#  631: 'simple',
#  632: 'walk',
#  633: 'poly',
#  634: 'msgs',
#  635: 'forget',
#  636: 'order',
#  637: 'drive',
#  638: 'smoke',
#  639: 'calling',
#  640: 'each',
#  641: 'either',
#  642: 'til',
#  643: 'email',
#  644: 'gr8',
#  645: "we'll",
#  646: 'w',
#  647: 'neva',
#  648: 'head',
#  649: 'å£500',
#  650: 'taking',
#  651: 'pounds',
#  652: 'pm',
#  653: 'everyone',
#  654: 'wants',
#  655: 'services',
#  656: 'yours',
#  657: 'minute',
#  658: 'anyone',
#  659: 'xx',
#  660: '86688',
#  661: 'smth',
#  662: 'fast',
#  663: 'book',
#  664: 'worth',
#  665: 'address',
#  666: 'info',
#  667: 'whatever',
#  668: 'statement',
#  669: 'expires',
#  670: 'lots',
#  671: 'lesson',
#  672: 'story',
#  673: 'girls',
#  674: 'operator',
#  675: 'auction',
#  676: 'company',
#  677: 'available',
#  678: 'started',
#  679: 'sister',
#  680: 'sae',
#  681: 'post',
#  682: 'angry',
#  683: 'card',
#  684: 'finally',
#  685: 'old',
#  686: 'mobileupd8',
#  687: 'close',
#  688: "haven't",
#  689: 'anytime',
#  690: 'winner',
#  691: 'search',
#  692: 'comes',
#  693: "she's",
#  694: 'opt',
#  695: 'sounds',
#  696: 'land',
#  697: 'weeks',
#  698: 'loving',
#  699: 'identifier',
#  700: '11',
#  701: 'whats',
#  702: 'frnd',
#  703: 'sea',
#  704: 'dating',
#  705: 'mine',
#  706: 'parents',
#  707: 'sis',
#  708: '12hrs',
#  709: "you've",
#  710: 'took',
#  711: 'needs',
#  712: 'quiz',
#  713: 'content',
#  714: 'await',
#  715: 'far',
#  716: 'dreams',
#  717: 'touch',
#  718: 'ten',
#  719: 'outside',
#  720: 'light',
#  721: 'å£3',
#  722: 'gone',
#  723: 'wrong',
#  724: 'college',
#  725: 'tho',
#  726: '08000839402',
#  727: 'ha',
#  728: 'earlier',
#  729: 'finished',
#  730: 'lucky',
#  731: 'news',
#  732: 'final',
#  733: 'ltd',
#  734: 'blue',
#  735: 'break',
#  736: 'rs',
#  737: 'mum',
#  738: 'bout',
#  739: 'fri',
#  740: 'alone',
#  741: 'hit',
#  742: 'crazy',
#  743: 'almost',
#  744: 'felt',
#  745: 'friday',
#  746: 'telling',
#  747: 'boytoy',
#  748: 'yar',
#  749: 'mate',
#  750: 'drop',
#  751: 'fancy',
#  752: "'",
#  753: 'lovely',
#  754: 'suite342',
#  755: '2lands',
#  756: 'knw',
#  757: 'whole',
#  758: 'side',
#  759: 'fucking',
#  760: 'least',
#  761: 'saying',
#  762: '100',
#  763: 'txts',
#  764: 'second',
#  765: 'player',
#  766: 'visit',
#  767: 'voucher',
#  768: '750',
#  769: 'couple',
#  770: 'decided',
#  771: 'nt',
#  772: 'press',
#  773: '30',
#  774: 'bank',
#  775: 'used',
#  776: 'cause',
#  777: 'read',
#  778: 'hand',
#  779: 'motorola',
#  780: 'congratulations',
#  781: 'o',
#  782: 'christmas',
#  783: 'wit',
#  784: 'type',
#  785: 'don',
#  786: 'case',
#  787: '800',
#  788: 'un',
#  789: 'party',
#  790: 'goodmorning',
#  791: 'credit',
#  792: 'b4',
#  793: 'hard',
#  794: '\x89û',
#  795: 'age',
#  796: 'welcome',
#  797: 'choose',
#  798: 'their',
#  799: 'kind',
#  800: 'balance',
#  801: 'currently',
#  802: 'tired',
#  803: 'f',
#  804: 'tc',
#  805: 'india',
#  806: 'freemsg',
#  807: 'etc',
#  808: 'sending',
#  809: 'congrats',
#  810: 'chennai',
#  811: 'seeing',
#  812: 'st',
#  813: 'project',
#  814: 'course',
#  815: 'caller',
#  816: 'unlimited',
#  817: 'gas',
#  818: 'pass',
#  819: 'march',
#  820: 'happiness',
#  821: 'understand',
#  822: 'semester',
#  823: 'sun',
#  824: 'reason',
#  825: 'park',
#  826: 'oredi',
#  827: 'ni8',
#  828: 'mrng',
#  829: 'found',
#  830: 'cum',
#  831: 'sunday',
#  832: 'difficult',
#  833: 'confirm',
#  834: 'frm',
#  835: "doesn't",
#  836: 'darlin',
#  837: 'savamob',
#  838: 'offers',
#  839: 'point',
#  840: "you'll",
#  841: 'hold',
#  842: 'nope',
#  843: 'red',
#  844: 'wkly',
#  845: 'wonderful',
#  846: '2003',
#  847: 'redeemed',
#  848: '04',
#  849: 'ends',
#  850: 'na',
#  851: 'cut',
#  852: 'hmm',
#  853: 'open',
#  854: 'seen',
#  855: "i'd",
#  856: 'via',
#  857: 'dogging',
#  858: 'sex',
#  859: 'supposed',
#  860: 'support',
#  861: 'hg',
#  862: 'mah',
#  863: 'bath',
#  864: 'father',
#  865: 'truth',
#  866: 'gn',
#  867: 'download',
#  868: 'feels',
#  869: 'pobox',
#  870: 'ac',
#  871: 'sort',
#  872: 'hows',
#  873: 'extra',
#  874: 'ans',
#  875: 'numbers',
#  876: 'å£350',
#  877: 'direct',
#  878: 'correct',
#  879: 'asap',
#  880: 'heard',
#  881: 'tel',
#  882: 'loved',
#  883: 'hmmm',
#  884: 'ipod',
#  885: '03',
#  886: 'wana',
#  887: 'gal',
#  888: 'loads',
#  889: 'yr',
#  890: 'mayb',
#  891: 'treat',
#  892: 'log',
#  893: 'reading',
#  894: 'darren',
#  895: 'talking',
#  896: 'questions',
#  897: 'monday',
#  898: 'saturday',
#  899: 'charged',
#  900: 'somebody',
#  901: 'move',
#  902: 'swing',
#  903: 'ago',
#  904: 'wap',
#  905: 'mr',
#  906: 'reward',
#  907: 'area',
#  908: 'carlos',
#  909: 'thinks',
#  910: 'mom',
#  911: 'hungry',
#  912: 'dnt',
#  913: 'fr',
#  914: 'snow',
#  915: '87066',
#  916: 'own',
#  917: 'slowly',
#  918: 'prob',
#  919: 'askd',
#  920: 'lost',
#  921: 'hee',
#  922: 'rply',
#  923: 'through',
#  924: 'enter',
#  925: 'nyt',
#  926: 'film',
#  927: 'å£250',
#  928: 'custcare',
#  929: 'sell',
#  930: 'rock',
#  931: 'fone',
#  932: 'ringtones',
#  933: '0800',
#  934: 'reached',
#  935: 'listen',
#  936: 'met',
#  937: 'frnds',
#  938: 'wishing',
#  939: "wasn't",
#  940: 'clean',
#  941: 'safe',
#  942: 'booked',
#  943: 'laptop',
#  944: 'camcorder',
#  945: '08000930705',
#  946: '12',
#  947: 'call2optout',
#  948: 'il',
#  949: 'match',
#  950: 'ex',
#  951: 'entered',
#  952: 'happened',
#  953: 'abiola',
#  954: 'kids',
#  955: 'usual',
#  956: 'eg',
#  957: 'exam',
#  958: 'secret',
#  959: 'tickets',
#  960: 'woke',
#  961: 'study',
#  962: 'takes',
#  963: 'leaves',
#  964: 'callertune',
#  965: 'meant',
#  966: 'discount',
#  967: 'lovable',
#  968: 'pretty',
#  969: 'valued',
#  970: 'computer',
#  971: 'remove',
#  972: 'sony',
#  973: 'std',
#  974: 'england',
#  975: 'song',
#  976: 'bcoz',
#  977: 'picking',
#  978: 'grins',
#  979: 'water',
#  980: 'mu',
#  981: 'crave',
#  982: 'checking',
#  983: "b'day",
#  984: 'gettin',
#  985: 'gym',
#  986: 'hmv',
#  987: 'ge',
#  988: 'wow',
#  989: 'promise',
#  990: 'especially',
#  991: 'doctor',
#  992: 'gave',
#  993: 'across',
#  994: '2nite',
#  995: 'surprise',
#  996: 'w1j6hl',
#  997: 'noon',
#  998: 'uncle',
#  999: 'john',
#  1000: 'kinda',
#  ...}

# %% [markdown]
# #Creating model and Adding the layers

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %% [markdown]
# #Compile the model

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam",
metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           263296
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 318,537
# Trainable params: 318,537
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Fit the model

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
validation_split=0.2,

workers=10,
callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 15s 404ms/step - loss: 0.4437 - accuracy: 0.8585 - val_loss: 0.2573 - val_accuracy: 0.8755
# Epoch 2/10
# 30/30 [==============================] - 11s 379ms/step - loss: 0.1813 - accuracy: 0.9485 - val_loss: 0.1088 - val_accuracy: 0.9736

# %% [markdown]
# #Save the model

# %%
lstm_model.save('sms.h5')

# %% [markdown]
# #Test the model

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 1s 35ms/step - loss: 0.0991 - accuracy: 0.9773

# %%
print('Test set\n Loss: {:0.3f}\n Accuracy:{:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#  Loss: 0.099
#  Accuracy:0.977
